# %%
import pickle as pk
import numpy as np

# %%
import cv2

# %%
file_name = "D:/Research/Data Files/sim_data/iteration 00/gamma=1.83134_reg_param=1.49685_iter=0_date=2025-06-22/data/simulation_module-25-06-22-00-51/step-00200.pickle"

with open(file_name, 'rb') as file:
    c_data_tuple = pk.load(file)  # this is the model feature outputs or embeddings

# %%
c_data_tuple
# Out:
# {'cellStates': {32: <CellModeller.CellState.CellState at 0x14cd2669090>,
#   38: <CellModeller.CellState.CellState at 0x14c827e10f0>,
#   46: <CellModeller.CellState.CellState at 0x14c82779330>,
#   56: <CellModeller.CellState.CellState at 0x14c827790f0>,
#   57: <CellModeller.CellState.CellState at 0x14c82764bb0>,
#   63: <CellModeller.CellState.CellState at 0x14c8269df90>,
#   67: <CellModeller.CellState.CellState at 0x14c825dca90>,
#   71: <CellModeller.CellState.CellState at 0x14c825dcbb0>,
#   76: <CellModeller.CellState.CellState at 0x14c82790c10>,
#   77: <CellModeller.CellState.CellState at 0x14c827c5ff0>,
#   78: <CellModeller.CellState.CellState at 0x14c8251c8b0>,
#   82: <CellModeller.CellState.CellState at 0x14c8251e530>,
#   86: <CellModeller.CellState.CellState at 0x14c8251c520>,
#   87: <CellModeller.CellState.CellState at 0x14c825e1870>,
#   97: <CellModeller.CellState.CellState at 0x14c825e18d0>,
#   98: <CellModeller.CellState.CellState at 0x14c825e1c90>,
# ...

# %%
c_data_tuple.keys()
# Out:
# dict_keys(['cellStates', 'stepNum', 'lineage', 'moduleStr', 'moduleName'])
